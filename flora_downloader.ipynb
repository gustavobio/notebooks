# %%
from requests_html import HTML, HTMLSession
import requests

# %%
session = HTMLSession()
r = session.get('http://ipt.jbrj.gov.br/jbrj/resource?r=lista_especies_flora_brasil')

# %%
links = r.html.find('a', containing = "DwC-A", first = True)

# %%
def download_file(url, local_filename = "dwca.zip"):
    local_filename = local_filename
    # NOTE the stream=True parameter below
    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        with open(local_filename, 'wb') as f:
            for chunk in r.iter_content(chunk_size=8192): 
                if chunk: # filter out keep-alive new chunks
                    f.write(chunk)
                    # f.flush()
    return local_filename

# %%
download_file(links.attrs['href'])
# Out:
# 'dwca.zip'

# %%
import zipfile
with zipfile.ZipFile("dwca.zip","r") as zip_ref:
    zip_ref.extractall("flora/")

# %%
import pandas as pd

# %%
flora = pd.read_csv("flora/taxon.txt", sep = "\t")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (9,12,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
flora
# Out:
#             id  taxonID  acceptedNameUsageID  parentNameUsageID  \
# 0           12       12                  NaN           120181.0
# 1           13       13                  NaN           120181.0
# 2           14       14                  NaN           120181.0
# 3           15       15                  NaN           120181.0
# 4           16       16                  NaN           120180.0
# 5           17       17                  NaN           120181.0
# 6           18       18                  NaN           120180.0
# 7           21       21                  NaN           120180.0
# 8           22       22                  NaN           120181.0
# 9           23       23                  NaN           120181.0
# 10          24       24                  NaN           120181.0
# 11          25       25                  NaN           120181.0
# 12          26       26                  NaN           120180.0
# 13          27       27                  NaN           120170.0
# 14          33       33                  NaN                NaN
# 15          34       34                  NaN                NaN
# 16          35       35                  NaN                NaN
# 17          36       36                  NaN                NaN
# 18          37       37              34091.0                NaN
# 19          38       38                  NaN                NaN
# 20          39       39                  NaN                NaN
# 21          40       40                 43.0                NaN
# 22          41       41                  NaN                NaN
# 23          42       42                  NaN                NaN
# 24          43       43                  NaN                NaN
# 25          44       44                  NaN                NaN
# 26          46       46                  NaN                NaN
# 27          47       47                  NaN                NaN
# 28          48       48                  NaN                NaN
# 29          49       49                  NaN                NaN
# ...        ...      ...                  ...                ...
# 121675  605666   605666                  NaN            15189.0
# 121676  605667   605667              12780.0            12735.0
# 121677  605668   605668              12780.0            12735.0
# 121678  605669   605669              12772.0            12735.0
# 121679  605670   605670              12772.0            12735.0
# 121680  605671   605671              12772.0            12735.0
# 121681  605672   605672              12772.0            12735.0
# 121682  605674   605674              12772.0            12735.0
# 121683  605675   605675                  NaN           604097.0
# 121684  605676   605676              87074.0            87073.0
# 121685  605677   605677              81695.0             6744.0
# 121686  605678   605678              22429.0             6731.0
# 121687  605679   605679                  NaN           604473.0
# 121688  605680   605680             605679.0             6746.0
# 121689  605681   605681             605679.0             6746.0
# 121690  605682   605682             101619.0             9442.0
# 121691  605683   605683              25766.0            25729.0
# 121692  605686   605686                  NaN            97818.0
# 121693  605687   605687                  NaN           605686.0
# 121694  605688   605688              19967.0            10982.0
# 121695  605689   605689              19967.0            10982.0
# 121696  605690   605690              10984.0            10982.0
# 121697  605691   605691                  NaN            12506.0
# 121698  605692   605692                  NaN            10338.0
# 121699  605693   605693              81691.0           604634.0
# 121700  605694   605694               6791.0           604097.0
# 121701  605698   605698                  NaN            23084.0
# 121702  605699   605699              13639.0           130030.0
# 121703  605700   605700               6791.0             6797.0
# 121704  605701   605701               6778.0            81683.0
#
#         originalNameUsageID  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22                      NaN
# 23                      NaN
# 24                      NaN
# 25                      NaN
# 26                      NaN
# 27                      NaN
# 28                      NaN
# 29                      NaN
# ...                     ...
# 121675                  NaN
# 121676             599630.0
# 121677                  NaN
# 121678                  NaN
# 121679                  NaN
# 121680                  NaN
# 121681                  NaN
# 121682                  NaN
# 121683             604718.0
# 121684                  NaN
# 121685              81695.0
# 121686             595835.0
# 121687             605681.0
# 121688                  NaN
# 121689             605679.0
# 121690                  NaN
# 121691                  NaN
# 121692                  NaN
# 121693                  NaN
# 121694                  NaN
# 121695                  NaN
# 121696                  NaN
# 121697                  NaN
# 121698                  NaN
# 121699             597545.0
# 121700             604719.0
# 121701                  NaN
# 121702                  NaN
# 121703             604721.0
# 121704                  NaN
#
#                                            scientificName  \
# 0                                              Agaricales
# 1                                          Auriculariales
# 2                                  Boletales E.-J.Gilbert
# 3                                              Geastrales
# 4                                              Helotiales
# 5                                  Hymenochaetales Oberw.
# 6                                             Hypocreales
# 7                                    Pezizales J. Schröt.
# 8                                       Phallales Fischer
# 9                                       Polyporales Gäum.
# 10                  Russulales Kreisel ex P.M.Kirk et al.
# 11                                            Pucciniales
# 12                                             Xylariales
# 13                                         Ceratiomyxales
# 14                                      Acanthaceae Juss.
# 15                                      Achariaceae Harms
# 16                                Achatocarpaceae Heimerl
# 17                                       Adoxaceae E.Mey.
# 18                                      Agavaceae Dumort.
# 19                                     Aizoaceae Martinov
# 20                                     Alismataceae Vent.
# 21                                       Alliaceae Borkh.
# 22                               Alstroemeriaceae Dumort.
# 23                                  Amaranthaceae A.Juss.
# 24                             Amaryllidaceae J. St.-Hil.
# 25                                    Anacardiaceae R.Br.
# 26                                 Anisophylleaceae Ridl.
# 27                                        Apiaceae Lindl.
# 28                                      Apocynaceae Juss.
# 29                         Apodanthaceae Tiegh. ex Takht.
# ...                                                   ...
# 121675            Stachytarpheta atkinsiae Harley & Giul.
# 121676                       Piper salicariaefolium Kunth
# 121677                          Piper rectinervulum C.DC.
# 121678                              Piper belemense C.DC.
# 121679                          Piper oblongilimbum C.DC.
# 121680                               Piper guedesii C.DC.
# 121681                           Piper glabrilimbum C.DC.
# 121682                             Piper apiculatum C.DC.
# 121683                  Tonsella glomerata (Mart.) G. Don
# 121684      Steyermarkochloa unifolia Davidse & R.P.Ellis
# 121685                 Hippocratea opacifolia J.F. Macbr.
# 121686                       Anthodon grandiflorus Benth.
# 121687         Monteverdia fugax (Biral & Lombardi) Biral
# 121688                 Maytenus nemorosa Biral & Lombardi
# 121689                    Maytenus fugax Biral & Lombardi
# 121690                       Clidemia pussiliflora Hoehne
# 121691     Ayenia bahiensis (Cristóbal) Christenh. & Byng
# 121692                                    Leimitra Lindb.
# 121693                           Leimitra flaccida Spruce
# 121694                    Agonandra duckei Huber ex Ducke
# 121695                        Agonandra granatensis Rusby
# 121696                      Agonandra spegazzinii Molfino
# 121697                     Passiflora bernaccii Mezzonato
# 121698                Eugenia salacifolia Bünger & Mazine
# 121699              Termophila macrophylla (Miquel) Miers
# 121700              Tonsella oblongifolia (Mart.) Spreng.
# 121701  Mimosa caccavariana J.Santos-Silva & A.M.G.Aze...
# 121702  Stipa quinqueciliata (Roseng. & Izag.) Zanin &...
# 121703     Tontelea obtusifolia (Cambess.) Endl. ex Walp.
# 121704               Salacia laevigata subsp. ovata Peyr.
#
#                                         acceptedNameUsage  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 9                                                     NaN
# 10                                                    NaN
# 11                                                    NaN
# 12                                                    NaN
# 13                                                    NaN
# 14                                                    NaN
# 15                                                    NaN
# 16                                                    NaN
# 17                                                    NaN
# 18                                     Asparagaceae Juss.
# 19                                                    NaN
# 20                                                    NaN
# 21                             Amaryllidaceae J. St.-Hil.
# 22                                                    NaN
# 23                                                    NaN
# 24                                                    NaN
# 25                                                    NaN
# 26                                                    NaN
# 27                                                    NaN
# 28                                                    NaN
# 29                                                    NaN
# ...                                                   ...
# 121675                                                NaN
# 121676                        Piper gaudichaudianum Kunth
# 121677                        Piper gaudichaudianum Kunth
# 121678                           Piper divaricatum G.Mey.
# 121679                           Piper divaricatum G.Mey.
# 121680                           Piper divaricatum G.Mey.
# 121681                           Piper divaricatum G.Mey.
# 121682                           Piper divaricatum G.Mey.
# 121683                                                NaN
# 121684      Steyermarkochloa angustifolia (Spreng.) Judz.
# 121685            Salacia opacifolia (J.F.Macbr.) A.C.Sm.
# 121686              Salacia impressifolia (Miers) A.C.Sm.
# 121687                                                NaN
# 121688         Monteverdia fugax (Biral & Lombardi) Biral
# 121689         Monteverdia fugax (Biral & Lombardi) Biral
# 121690                        Miconia aliquantula Wurdack
# 121691                        Rayleya bahiensis Cristóbal
# 121692                                                NaN
# 121693                                                NaN
# 121694  Agonandra brasiliensis Miers ex Benth. & Hook....
# 121695  Agonandra brasiliensis Miers ex Benth. & Hook....
# 121696                          Agonandra excelsa Griseb.
# 121697                                                NaN
# 121698                                                NaN
# 121699                           Salacia miqueliana Loes.
# 121700                    Salacia elliptica (Mart.) G.Don
# 121701                                                NaN
# 121702  Nassella quinqueciliata (Roseng. & Izag.) Bark...
# 121703                    Salacia elliptica (Mart.) G.Don
# 121704   Peritassa laevigata (Hoffmanns. ex Link) A.C.Sm.
#
#                                    parentNameUsage  \
# 0                                    Basidiomycota
# 1                                    Basidiomycota
# 2                                    Basidiomycota
# 3                                    Basidiomycota
# 4                            Ascomycota Caval.-Sm.
# 5                                    Basidiomycota
# 6                            Ascomycota Caval.-Sm.
# 7                            Ascomycota Caval.-Sm.
# 8                                    Basidiomycota
# 9                                    Basidiomycota
# 10                                   Basidiomycota
# 11                                   Basidiomycota
# 12                           Ascomycota Caval.-Sm.
# 13                                      Myxomycota
# 14                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                                             NaN
# 18                                             NaN
# 19                                             NaN
# 20                                             NaN
# 21                                             NaN
# 22                                             NaN
# 23                                             NaN
# 24                                             NaN
# 25                                             NaN
# 26                                             NaN
# 27                                             NaN
# 28                                             NaN
# 29                                             NaN
# ...                                            ...
# 121675                         Stachytarpheta Vahl
# 121676                                    Piper L.
# 121677                                    Piper L.
# 121678                                    Piper L.
# 121679                                    Piper L.
# 121680                                    Piper L.
# 121681                                    Piper L.
# 121682                                    Piper L.
# 121683                            Tonsella Schreb.
# 121684        Steyermarkochloa Davidse & R.P.Ellis
# 121685                              Hippocratea L.
# 121686                        Anthodon Ruiz & Pav.
# 121687                        Monteverdia A. Rich.
# 121688                             Maytenus Molina
# 121689                             Maytenus Molina
# 121690                              Clidemia D.Don
# 121691                                   Ayenia L.
# 121692                    Trichocoleaceae K. Müll.
# 121693                             Leimitra Lindb.
# 121694         Agonandra Miers ex Benth. & Hook.f.
# 121695         Agonandra Miers ex Benth. & Hook.f.
# 121696         Agonandra Miers ex Benth. & Hook.f.
# 121697                               Passiflora L.
# 121698                                  Eugenia L.
# 121699                            Termophila Miers
# 121700                            Tonsella Schreb.
# 121701                                   Mimosa L.
# 121702                                    Stipa L.
# 121703                              Tontelea Miers
# 121704  Salacia laevigata (Hoffmanns. ex Link) DC.
#
#                                           namePublishedIn namePublishedInYear  \
# 0                                                     NaN                 NaN
# 1                                                     NaN                 NaN
# 2                                                     NaN                 NaN
# 3                                                     NaN                 NaN
# 4                                                     NaN                 NaN
# 5                                                     NaN                 NaN
# 6                                                     NaN                 NaN
# 7                                                     NaN                 NaN
# 8                                                     NaN                 NaN
# 9                                                     NaN                 NaN
# 10                                                    NaN                 NaN
# 11                                                    NaN                 NaN
# 12                                                    NaN                 NaN
# 13                                                    NaN                 NaN
# 14                                                    NaN                 NaN
# 15                                                    NaN                 NaN
# 16                                                    NaN                 NaN
# 17                                                    NaN                 NaN
# 18                                                    NaN                 NaN
# 19                                                    NaN                 NaN
# 20                                                    NaN                 NaN
# 21                                                    NaN                 NaN
# 22                                                    NaN                 NaN
# 23                                                    NaN                 NaN
# 24                                                    NaN                 NaN
# 25                                                    NaN                 NaN
# 26                                                    NaN                 NaN
# 27                                                    NaN                 NaN
# 28                                                    NaN                 NaN
# 29                                                    NaN                 NaN
# ...                                                   ...                 ...
# 121675                             Phytotaxa 401/127 2019                2019
# 121676                                                NaN                 NaN
# 121677                                                NaN                 NaN
# 121678                                                NaN                 NaN
# 121679                                                NaN                 NaN
# 121680                                                NaN                 NaN
# 121681                                                NaN                 NaN
# 121682                                                NaN                 NaN
# 121683                       Mant. (Schultes) 1: 348 1822                1822
# 121684  Ann. Missouri Bot. Gard. 71(4): 995, f. 1–27 1984                1984
# 121685  Publ. Field Mus. Nat. Hist., Bot. Ser. 8(2): 1...                1930
# 121686        Hooker's J. Bot. Kew Gard. Misc. 4: 10 1852                1852
# 121687                          Phytotaxa 261(1): 99 2016                2016
# 121688                          Phytotaxa 231(1): 57 2015                2015
# 121689                          Phytotaxa 261(1): 99 2016                2016
# 121690  Anexos Mem. Inst. Butantan, Secc. Bot. 1(5):16...                1922
# 121691                                                NaN                 NaN
# 121692                                                NaN                 NaN
# 121693                                                NaN                 NaN
# 121694                                                NaN                 NaN
# 121695            Descr. S. Amer. Pl. vol. único: 14 1920                1920
# 121696              Anales Soc. Ci. Argent. 108: 140 1929                1929
# 121697                                                NaN                 NaN
# 121698                            Kew Bulletin 73:38 2018                2018
# 121699     Trans. Linn. Soc. London, Bot. 28(2): 399 1872                1872
# 121700                             Syst. Veg. 1: 178 1824                1824
# 121701                                                NaN                 NaN
# 121702                                                NaN                 NaN
# 121703                     Repert. Bot. Syst. 1: 400 1842                1842
# 121704  Trans. Linn. Soc. London, Bot. 28(2): 406-407 ...                1872
#
#         ...             genus   specificEpithet infraspecificEpithet  \
# 0       ...               NaN               NaN                  NaN
# 1       ...               NaN               NaN                  NaN
# 2       ...               NaN               NaN                  NaN
# 3       ...               NaN               NaN                  NaN
# 4       ...               NaN               NaN                  NaN
# 5       ...               NaN               NaN                  NaN
# 6       ...               NaN               NaN                  NaN
# 7       ...               NaN               NaN                  NaN
# 8       ...               NaN               NaN                  NaN
# 9       ...               NaN               NaN                  NaN
# 10      ...               NaN               NaN                  NaN
# 11      ...               NaN               NaN                  NaN
# 12      ...               NaN               NaN                  NaN
# 13      ...               NaN               NaN                  NaN
# 14      ...               NaN               NaN                  NaN
# 15      ...               NaN               NaN                  NaN
# 16      ...               NaN               NaN                  NaN
# 17      ...               NaN               NaN                  NaN
# 18      ...               NaN               NaN                  NaN
# 19      ...               NaN               NaN                  NaN
# 20      ...               NaN               NaN                  NaN
# 21      ...               NaN               NaN                  NaN
# 22      ...               NaN               NaN                  NaN
# 23      ...               NaN               NaN                  NaN
# 24      ...               NaN               NaN                  NaN
# 25      ...               NaN               NaN                  NaN
# 26      ...               NaN               NaN                  NaN
# 27      ...               NaN               NaN                  NaN
# 28      ...               NaN               NaN                  NaN
# 29      ...               NaN               NaN                  NaN
# ...     ...               ...               ...                  ...
# 121675  ...    Stachytarpheta         atkinsiae                  NaN
# 121676  ...             Piper  salicariaefolium                  NaN
# 121677  ...             Piper     rectinervulum                  NaN
# 121678  ...             Piper         belemense                  NaN
# 121679  ...             Piper     oblongilimbum                  NaN
# 121680  ...             Piper          guedesii                  NaN
# 121681  ...             Piper      glabrilimbum                  NaN
# 121682  ...             Piper        apiculatum                  NaN
# 121683  ...          Tonsella         glomerata                  NaN
# 121684  ...  Steyermarkochloa          unifolia                  NaN
# 121685  ...       Hippocratea        opacifolia                  NaN
# 121686  ...          Anthodon      grandiflorus                  NaN
# 121687  ...       Monteverdia             fugax                  NaN
# 121688  ...          Maytenus          nemorosa                  NaN
# 121689  ...          Maytenus             fugax                  NaN
# 121690  ...          Clidemia      pussiliflora                  NaN
# 121691  ...            Ayenia         bahiensis                  NaN
# 121692  ...          Leimitra               NaN                  NaN
# 121693  ...          Leimitra          flaccida                  NaN
# 121694  ...         Agonandra            duckei                  NaN
# 121695  ...         Agonandra       granatensis                  NaN
# 121696  ...         Agonandra       spegazzinii                  NaN
# 121697  ...        Passiflora         bernaccii                  NaN
# 121698  ...           Eugenia       salacifolia                  NaN
# 121699  ...        Termophila       macrophylla                  NaN
# 121700  ...          Tonsella      oblongifolia                  NaN
# 121701  ...            Mimosa      caccavariana                  NaN
# 121702  ...             Stipa    quinqueciliata                  NaN
# 121703  ...          Tontelea       obtusifolia                  NaN
# 121704  ...           Salacia         laevigata                ovata
#
#           taxonRank         scientificNameAuthorship taxonomicStatus  \
# 0             ORDEM                              NaN     NOME_ACEITO
# 1             ORDEM                              NaN     NOME_ACEITO
# 2             ORDEM                     E.-J.Gilbert     NOME_ACEITO
# 3             ORDEM                              NaN     NOME_ACEITO
# 4             ORDEM                              NaN     NOME_ACEITO
# 5             ORDEM                           Oberw.     NOME_ACEITO
# 6             ORDEM                              NaN     NOME_ACEITO
# 7             ORDEM                       J. Schröt.     NOME_ACEITO
# 8             ORDEM                          Fischer     NOME_ACEITO
# 9             ORDEM                            Gäum.     NOME_ACEITO
# 10            ORDEM       Kreisel ex P.M.Kirk et al.     NOME_ACEITO
# 11            ORDEM                              NaN     NOME_ACEITO
# 12            ORDEM                              NaN     NOME_ACEITO
# 13            ORDEM                              NaN     NOME_ACEITO
# 14          FAMILIA                            Juss.     NOME_ACEITO
# 15          FAMILIA                            Harms     NOME_ACEITO
# 16          FAMILIA                          Heimerl     NOME_ACEITO
# 17          FAMILIA                           E.Mey.     NOME_ACEITO
# 18          FAMILIA                          Dumort.        SINONIMO
# 19          FAMILIA                         Martinov     NOME_ACEITO
# 20          FAMILIA                            Vent.     NOME_ACEITO
# 21          FAMILIA                           Borkh.        SINONIMO
# 22          FAMILIA                          Dumort.     NOME_ACEITO
# 23          FAMILIA                          A.Juss.     NOME_ACEITO
# 24          FAMILIA                      J. St.-Hil.     NOME_ACEITO
# 25          FAMILIA                            R.Br.     NOME_ACEITO
# 26          FAMILIA                            Ridl.     NOME_ACEITO
# 27          FAMILIA                           Lindl.     NOME_ACEITO
# 28          FAMILIA                            Juss.     NOME_ACEITO
# 29          FAMILIA                 Tiegh. ex Takht.     NOME_ACEITO
# ...             ...                              ...             ...
# 121675      ESPECIE                   Harley & Giul.     NOME_ACEITO
# 121676      ESPECIE                            Kunth        SINONIMO
# 121677      ESPECIE                            C.DC.        SINONIMO
# 121678      ESPECIE                            C.DC.        SINONIMO
# 121679      ESPECIE                            C.DC.        SINONIMO
# 121680      ESPECIE                            C.DC.        SINONIMO
# 121681      ESPECIE                            C.DC.        SINONIMO
# 121682      ESPECIE                            C.DC.        SINONIMO
# 121683      ESPECIE                   (Mart.) G. Don        SINONIMO
# 121684      ESPECIE              Davidse & R.P.Ellis        SINONIMO
# 121685      ESPECIE                      J.F. Macbr.        SINONIMO
# 121686      ESPECIE                           Benth.        SINONIMO
# 121687      ESPECIE         (Biral & Lombardi) Biral     NOME_ACEITO
# 121688      ESPECIE                 Biral & Lombardi        SINONIMO
# 121689      ESPECIE                 Biral & Lombardi        SINONIMO
# 121690      ESPECIE                           Hoehne        SINONIMO
# 121691      ESPECIE    (Cristóbal) Christenh. & Byng        SINONIMO
# 121692       GENERO                           Lindb.     NOME_ACEITO
# 121693      ESPECIE                           Spruce     NOME_ACEITO
# 121694      ESPECIE                   Huber ex Ducke        SINONIMO
# 121695      ESPECIE                            Rusby        SINONIMO
# 121696      ESPECIE                          Molfino        SINONIMO
# 121697      ESPECIE                        Mezzonato     NOME_ACEITO
# 121698      ESPECIE                  Bünger & Mazine     NOME_ACEITO
# 121699      ESPECIE                   (Miquel) Miers        SINONIMO
# 121700      ESPECIE                  (Mart.) Spreng.        SINONIMO
# 121701      ESPECIE   J.Santos-Silva & A.M.G.Azevedo     NOME_ACEITO
# 121702      ESPECIE  (Roseng. & Izag.) Zanin & Izag.        SINONIMO
# 121703      ESPECIE        (Cambess.) Endl. ex Walp.        SINONIMO
# 121704  SUB_ESPECIE                            Peyr.        SINONIMO
#
#                    nomenclaturalStatus                 modified  \
# 0                         NOME_CORRETO  2018-08-10 11:58:06.954
# 1                         NOME_CORRETO  2014-09-26 11:01:06.918
# 2                         NOME_CORRETO  2014-09-05 13:54:33.185
# 3                         NOME_CORRETO  2015-03-05 17:48:09.918
# 4                         NOME_CORRETO  2014-03-17 08:17:41.765
# 5                         NOME_CORRETO   2014-09-26 12:58:50.51
# 6                         NOME_CORRETO  2015-03-07 13:02:06.304
# 7                         NOME_CORRETO   2015-03-06 14:59:22.16
# 8                         NOME_CORRETO  2015-02-20 21:12:29.429
# 9                         NOME_CORRETO  2015-03-07 14:48:38.997
# 10                        NOME_CORRETO  2014-09-26 14:00:08.462
# 11                        NOME_CORRETO  2015-03-04 17:58:12.476
# 12                        NOME_CORRETO  2015-02-02 09:14:52.026
# 13                        NOME_CORRETO  2019-04-13 12:46:02.746
# 14                        NOME_CORRETO  2019-02-21 09:32:46.538
# 15                        NOME_CORRETO  2019-04-13 08:10:15.267
# 16                        NOME_CORRETO  2017-07-17 10:16:00.335
# 17                        NOME_CORRETO  2018-12-25 10:30:49.118
# 18                                 NaN  2018-10-25 11:38:54.472
# 19                        NOME_CORRETO  2017-07-28 16:27:45.161
# 20                        NOME_CORRETO  2019-03-20 15:05:49.043
# 21         NOME_LEGITIMO_MAS_INCORRETO  2017-09-11 17:18:11.275
# 22                        NOME_CORRETO  2018-08-10 15:10:14.661
# 23                        NOME_CORRETO  2019-04-17 13:26:59.267
# 24        NOME_CORRETO_VIA_CONSERVACAO  2019-04-24 21:08:40.512
# 25                        NOME_CORRETO  2018-06-30 19:50:35.652
# 26                        NOME_CORRETO  2018-02-05 16:55:04.645
# 27                        NOME_CORRETO   2018-05-16 11:33:23.99
# 28                        NOME_CORRETO  2019-01-22 11:38:47.473
# 29                        NOME_CORRETO  2017-01-17 14:18:23.583
# ...                                ...                      ...
# 121675                             NaN  2019-04-15 14:28:12.427
# 121676                             NaN  2019-04-15 14:37:38.659
# 121677                             NaN   2019-04-15 14:47:08.21
# 121678                             NaN  2019-04-15 14:56:12.193
# 121679                             NaN  2019-04-15 15:03:24.743
# 121680                             NaN   2019-04-15 15:16:20.12
# 121681                             NaN  2019-04-15 15:26:20.634
# 121682                             NaN  2019-04-15 15:53:48.127
# 121683     NOME_LEGITIMO_MAS_INCORRETO  2019-04-15 20:13:39.092
# 121684                  NOME_REJEITADO  2019-04-16 13:08:21.548
# 121685     NOME_LEGITIMO_MAS_INCORRETO  2019-04-30 17:48:56.417
# 121686     NOME_LEGITIMO_MAS_INCORRETO  2019-04-16 16:07:56.467
# 121687                    NOME_CORRETO  2019-04-16 19:16:08.672
# 121688                  NOME_ILEGITIMO  2019-04-16 19:03:08.251
# 121689     NOME_LEGITIMO_MAS_INCORRETO  2019-04-16 19:08:01.206
# 121690                             NaN  2019-04-24 12:29:29.221
# 121691     NOME_LEGITIMO_MAS_INCORRETO  2019-04-18 08:26:19.236
# 121692                    NOME_CORRETO  2019-04-19 14:08:43.793
# 121693                    NOME_CORRETO  2019-04-19 14:08:33.185
# 121694  NOME_NAO_VALIDAMENTE_PUBLICADO  2019-04-21 16:05:11.018
# 121695     NOME_LEGITIMO_MAS_INCORRETO  2019-04-20 19:24:50.478
# 121696     NOME_LEGITIMO_MAS_INCORRETO  2019-04-21 16:06:28.059
# 121697                    NOME_CORRETO  2019-04-23 16:36:27.297
# 121698                    NOME_CORRETO  2019-04-24 09:31:24.092
# 121699                  NOME_ILEGITIMO  2019-04-25 17:44:38.872
# 121700     NOME_LEGITIMO_MAS_INCORRETO   2019-04-29 21:01:03.42
# 121701                    NOME_CORRETO  2019-04-30 11:40:18.996
# 121702                             NaN  2019-04-30 15:17:00.056
# 121703     NOME_LEGITIMO_MAS_INCORRETO  2019-04-30 17:09:09.436
# 121704                  NOME_ILEGITIMO   2019-04-30 17:26:24.13
#
#                                     bibliographicCitation  \
# 0       Flora do Brasil 2020 em construção. Jardim Bot...
# 1       Flora do Brasil 2020 em construção. Jardim Bot...
# 2       Flora do Brasil 2020 em construção. Jardim Bot...
# 3       Flora do Brasil 2020 em construção. Jardim Bot...
# 4       Flora do Brasil 2020 em construção. Jardim Bot...
# 5       Flora do Brasil 2020 em construção. Jardim Bot...
# 6       Flora do Brasil 2020 em construção. Jardim Bot...
# 7       Flora do Brasil 2020 em construção. Jardim Bot...
# 8       Flora do Brasil 2020 em construção. Jardim Bot...
# 9       Flora do Brasil 2020 em construção. Jardim Bot...
# 10      Flora do Brasil 2020 em construção. Jardim Bot...
# 11      Flora do Brasil 2020 em construção. Jardim Bot...
# 12      Flora do Brasil 2020 em construção. Jardim Bot...
# 13      Flora do Brasil 2020 em construção. Jardim Bot...
# 14      Flora do Brasil 2020 em construção. Jardim Bot...
# 15      Flora do Brasil 2020 em construção. Jardim Bot...
# 16      Flora do Brasil 2020 em construção. Jardim Bot...
# 17      Flora do Brasil 2020 em construção. Jardim Bot...
# 18      Flora do Brasil 2020 em construção. Jardim Bot...
# 19      Flora do Brasil 2020 em construção. Jardim Bot...
# 20      Flora do Brasil 2020 em construção. Jardim Bot...
# 21      Flora do Brasil 2020 em construção. Jardim Bot...
# 22      Flora do Brasil 2020 em construção. Jardim Bot...
# 23      Flora do Brasil 2020 em construção. Jardim Bot...
# 24      Flora do Brasil 2020 em construção. Jardim Bot...
# 25      Flora do Brasil 2020 em construção. Jardim Bot...
# 26      Flora do Brasil 2020 em construção. Jardim Bot...
# 27      Flora do Brasil 2020 em construção. Jardim Bot...
# 28      Flora do Brasil 2020 em construção. Jardim Bot...
# 29      Flora do Brasil 2020 em construção. Jardim Bot...
# ...                                                   ...
# 121675  Flora do Brasil 2020 em construção. Jardim Bot...
# 121676  Flora do Brasil 2020 em construção. Jardim Bot...
# 121677  Flora do Brasil 2020 em construção. Jardim Bot...
# 121678  Flora do Brasil 2020 em construção. Jardim Bot...
# 121679  Flora do Brasil 2020 em construção. Jardim Bot...
# 121680  Flora do Brasil 2020 em construção. Jardim Bot...
# 121681  Flora do Brasil 2020 em construção. Jardim Bot...
# 121682  Flora do Brasil 2020 em construção. Jardim Bot...
# 121683  Flora do Brasil 2020 em construção. Jardim Bot...
# 121684  Flora do Brasil 2020 em construção. Jardim Bot...
# 121685  Flora do Brasil 2020 em construção. Jardim Bot...
# 121686  Flora do Brasil 2020 em construção. Jardim Bot...
# 121687  Flora do Brasil 2020 em construção. Jardim Bot...
# 121688  Flora do Brasil 2020 em construção. Jardim Bot...
# 121689  Flora do Brasil 2020 em construção. Jardim Bot...
# 121690  Flora do Brasil 2020 em construção. Jardim Bot...
# 121691  Flora do Brasil 2020 em construção. Jardim Bot...
# 121692  Flora do Brasil 2020 em construção. Jardim Bot...
# 121693  Flora do Brasil 2020 em construção. Jardim Bot...
# 121694  Flora do Brasil 2020 em construção. Jardim Bot...
# 121695  Flora do Brasil 2020 em construção. Jardim Bot...
# 121696  Flora do Brasil 2020 em construção. Jardim Bot...
# 121697  Flora do Brasil 2020 em construção. Jardim Bot...
# 121698  Flora do Brasil 2020 em construção. Jardim Bot...
# 121699  Flora do Brasil 2020 em construção. Jardim Bot...
# 121700  Flora do Brasil 2020 em construção. Jardim Bot...
# 121701  Flora do Brasil 2020 em construção. Jardim Bot...
# 121702  Flora do Brasil 2020 em construção. Jardim Bot...
# 121703  Flora do Brasil 2020 em construção. Jardim Bot...
# 121704  Flora do Brasil 2020 em construção. Jardim Bot...
#
#                                                references
# 0       http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 1       http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 2       http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 3       http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 4       http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 5       http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 6       http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 7       http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 8       http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 9       http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 10      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 11      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 12      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 13      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 14      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 15      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 16      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 17      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 18      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 19      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 20      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 21      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 22      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 23      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 24      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 25      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 26      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 27      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 28      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 29      http://reflora.jbrj.gov.br/reflora/listaBrasil...
# ...                                                   ...
# 121675  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121676  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121677  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121678  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121679  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121680  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121681  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121682  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121683  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121684  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121685  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121686  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121687  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121688  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121689  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121690  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121691  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121692  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121693  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121694  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121695  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121696  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121697  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121698  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121699  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121700  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121701  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121702  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121703  http://reflora.jbrj.gov.br/reflora/listaBrasil...
# 121704  http://reflora.jbrj.gov.br/reflora/listaBrasil...
#
# [121705 rows x 26 columns]
